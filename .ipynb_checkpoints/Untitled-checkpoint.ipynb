# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
file1 = pd.read_csv('/Users/pedro/Desktop/Ironhack/Unit 01/lab-customer-analysis-round-2/files_for_lab/csv_files/marketing_customer_analysis.csv')
file1
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %%
file1.shape
# Out:
# (10910, 26)

# %%
file1.columns = [file1.columns[i].lower().replace(' ', '_') for i in range(len(file1.columns))]
file1
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %%
file1.isna().sum()
# Out:
# unnamed:_0                          0
# customer                            0
# state                             631
# customer_lifetime_value             0
# response                          631
# coverage                            0
# education                           0
# effective_to_date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location_code                       0
# marital_status                      0
# monthly_premium_auto                0
# months_since_last_claim           633
# months_since_policy_inception       0
# number_of_open_complaints         633
# number_of_policies                  0
# policy_type                         0
# policy                              0
# renew_offer_type                    0
# sales_channel                       0
# total_claim_amount                  0
# vehicle_class                     622
# vehicle_size                      622
# ...

# %%
for i in file1.isna().columns:
    if file1.isna().sum()[i] !=0:
        data = file1.dropna()

# %%
data.isna().sum()
# Out:
# unnamed:_0                       0
# customer                         0
# state                            0
# customer_lifetime_value          0
# response                         0
# coverage                         0
# education                        0
# effective_to_date                0
# employmentstatus                 0
# gender                           0
# income                           0
# location_code                    0
# marital_status                   0
# monthly_premium_auto             0
# months_since_last_claim          0
# months_since_policy_inception    0
# number_of_open_complaints        0
# number_of_policies               0
# policy_type                      0
# policy                           0
# renew_offer_type                 0
# sales_channel                    0
# total_claim_amount               0
# vehicle_class                    0
# vehicle_size                     0
# vehicle_type                     0
# dtype: int64

# %%
categorical=data.select_dtypes('object')
categorical
# Out:
#       customer       state response  coverage             education  \
# 2      LZ68649  Washington       No     Basic              Bachelor
# 3      XL78013      Oregon      Yes  Extended               College
# 10     HG93801     Arizona       No  Extended  High School or Below
# 13     KR82385  California       No     Basic                Master
# 16     FH51383  California       No     Basic  High School or Below
# ...        ...         ...      ...       ...                   ...
# 10902  PP30874  California       No  Extended  High School or Below
# 10903  SU71163     Arizona       No     Basic               College
# 10904  QI63521      Nevada       No     Basic  High School or Below
# 10906  KX53892      Oregon       No     Basic               College
# 10908  WA60547  California       No   Premium               College
#
#       effective_to_date employmentstatus gender location_code marital_status  \
# ...

# %%
numerical=data.select_dtypes('number')
numerical
# Out:
#        unnamed:_0  customer_lifetime_value  income  monthly_premium_auto  \
# 2               2             14947.917300   22139                   100
# 3               3             22332.439460   49078                    97
# 10             10              5154.764074   82730                   127
# 13             13              5454.587929   66334                    69
# 16             16              5326.677654   76717                    66
# ...           ...                      ...     ...                   ...
# 10902       10902              3579.023825   28304                    91
# 10903       10903              2771.663013   59855                    74
# 10904       10904             19228.463620       0                   187
# 10906       10906              5259.444853   61146                    65
# 10908       10908             11971.977650   64195                   158
#
#        months_since_last_claim  months_since_policy_inception  \
# ...

# %%
data['effective_to_date'] = pd.to_datetime(data['effective_to_date'])
data['effective_to_date']
# Out:
# /var/folders/gc/x16qpdrd20ncx2ld2y3tfbmh0000gn/T/ipykernel_7450/3957364819.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['effective_to_date'] = pd.to_datetime(data['effective_to_date'])
# 2       2011-02-10
# 3       2011-01-11
# 10      2011-01-02
# 13      2011-01-26
# 16      2011-02-07
#            ...
# 10902   2011-01-24
# 10903   2011-01-07
# 10904   2011-02-24
# 10906   2011-01-06
# 10908   2011-02-13
# Name: effective_to_date, Length: 4543, dtype: datetime64[ns]

# %%
month_column=[]
for i in data['effective_to_date']:
    month_column.append(i.month)
data.insert(8,'month',month_column)

# %%
data[data['month'] <=3]
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 10             10  HG93801     Arizona              5154.764074       No
# 13             13  KR82385  California              5454.587929       No
# 16             16  FH51383  California              5326.677654       No
# ...           ...      ...         ...                      ...      ...
# 10902       10902  PP30874  California              3579.023825       No
# 10903       10903  SU71163     Arizona              2771.663013       No
# 10904       10904  QI63521      Nevada             19228.463620       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10908       10908  WA60547  California             11971.977650       No
#
#        coverage             education effective_to_date  month  \
# ...

# %%
data['response'].hist(bins=10,color='green')
plt.show()

# %%
sns.histplot(bins=1,data=data, x='sales_channel', hue='response')
plt.show()

# %%
sns.histplot(bins=10,data=data, x='total_claim_amount', hue='response')
plt.show()

# %%
sns.histplot(bins=10, data=data, x='income', hue='response')
plt.show()
